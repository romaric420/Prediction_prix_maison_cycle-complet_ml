# %% [markdown]
# # Exploratory Data Analysis — price prediction
# **Objectif** : hypothese.
#
# **Dataset** : `immobilier_dataset.csv`
# **Auteur** : Romaric TCHOFFO
# **Date** : 2026

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import binomtest, chisquare,ttest_1samp,chi2_contingency,ttest_ind,f_oneway,pearsonr,spearmanr,mannwhitneyu,kruskal
import numpy as np

# Load the dataset
data = pd.read_csv('../data/raw_data/immo_dataset_messy.csv')
df = data.copy()

df.head(2)
# Out:
#   OverallQual GrLivArea  TotalBsmtSF 1stFlrSF  YearBuilt  YearRemodAdd  \
# 0           4     157.8         92.9   882.31     1931.0        2018.0
# 1           6     117.1        101.0    720.4     1932.0        1974.0
#
#   GarageCars GarageArea  FullBath TotRmsAbvGrd  ... Fireplaces LotArea  \
# 0          1     570.38       1.0            2  ...          0   314.9
# 1          1     537.17       1.0            4  ...          1   305.3
#
#   Neighborhood ExterQual PropertyType  DPE HasPool AgentID    SaleDate  \
# 0   Belleville        TA         Loft  NaN       0     NaN  2015-02-02
# 1    Oberkampf        Gd       Studio    F       0     NaN   3/10/2022
#
#   SalePrice
# 0  807342.0
# 1  694289.0
#
# [2 rows x 21 columns]
